# %%
import numpy as np
import pandas as pd
import functions as fn

# %%
white_wine = pd.read_csv('../data/white_wine_cleaned.csv', sep='|')
red_wine = pd.read_csv('../data/red_wine_cleaned.csv', sep='|')

# %%
white_wine.head()
# Out:
#                                         vintage_name  \
# 0  Territorio Luthier Territorio Luthier Blanco 2020
# 1                                Ossian Capitel 2021
# 2        Remírez de Ganuza Rioja Blanco Reserva 2021
# 3    Abadía Retuerta LeDomaine Blanco de Guarda 2020
# 4    Abadía Retuerta LeDomaine Blanco de Guarda 2019
#
#                     wine_name  year            region              bodega  \
# 0   Territorio Luthier Blanco  2020  Ribera del Duero  Territorio Luthier
# 1                     Capitel  2021   Castilla y León              Ossian
# 2        Rioja Blanco Reserva  2021             Rioja   Remírez de Ganuza
# 3  LeDomaine Blanco de Guarda  2020   Abadía Retuerta     Abadía Retuerta
# 4  LeDomaine Blanco de Guarda  2019   Abadía Retuerta     Abadía Retuerta
#
#   varietal_name           grape_varieties  price   acidity  intensity  \
# 0         White    Albillo Mayor, Purulés  41.00  3.000000   3.294000
# ...

# %%
red_wine.head()
# Out:
#                      vintage_name        wine_name  year            region  \
# 0   Can Blau Mas de Can Blau 2020  Mas de Can Blau  2020          Montsant
# 1  Pago de Carraovejas Tinto 2020            Tinto  2020  Ribera del Duero
# 2       Bodegas El Nido Clio 2021             Clio  2021           Jumilla
# 3       Bodegas Vilano Tinto 2021            Tinto  2021  Ribera del Duero
# 4     Carmelo Rodero Reserva 2019          Reserva  2019  Ribera del Duero
#
#                 bodega              varietal_name  \
# 0             Can Blau          Tinto de Montsant
# 1  Pago de Carraovejas  Tinto de Ribera del Duero
# 2      Bodegas El Nido                 Monastrell
# 3       Bodegas Vilano  Tinto de Ribera del Duero
# 4       Carmelo Rodero  Tinto de Ribera del Duero
#
#                                      grape_varieties  price   acidity  \
# 0  Shiraz/Syrah, Cabernet Sauvignon, Cariñena, Ga...  32.45  3.311428
# ...

# %%
# going to join the datasets
all_wine = pd.concat([white_wine, red_wine])

# %%
all_wine.head()
# Out:
#                                         vintage_name  \
# 0  Territorio Luthier Territorio Luthier Blanco 2020
# 1                                Ossian Capitel 2021
# 2        Remírez de Ganuza Rioja Blanco Reserva 2021
# 3    Abadía Retuerta LeDomaine Blanco de Guarda 2020
# 4    Abadía Retuerta LeDomaine Blanco de Guarda 2019
#
#                     wine_name  year            region              bodega  \
# 0   Territorio Luthier Blanco  2020  Ribera del Duero  Territorio Luthier
# 1                     Capitel  2021   Castilla y León              Ossian
# 2        Rioja Blanco Reserva  2021             Rioja   Remírez de Ganuza
# 3  LeDomaine Blanco de Guarda  2020   Abadía Retuerta     Abadía Retuerta
# 4  LeDomaine Blanco de Guarda  2019   Abadía Retuerta     Abadía Retuerta
#
#   varietal_name           grape_varieties  price   acidity  intensity  \
# 0         White    Albillo Mayor, Purulés  41.00  3.000000   3.294000
# ...

# %%
all_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4051 entries, 0 to 2024
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   vintage_name          4051 non-null   object
#  1   wine_name             4051 non-null   object
#  2   year                  4051 non-null   object
#  3   region                4051 non-null   object
#  4   bodega                4051 non-null   object
#  5   varietal_name         4051 non-null   object
#  6   grape_varieties       4051 non-null   object
#  7   price                 4051 non-null   float64
#  8   acidity               4051 non-null   float64
#  9   intensity             4051 non-null   float64
#  10  sweetness             4051 non-null   float64
#  11  tannin                2025 non-null   float64
#  12  wine_ratings_count    4051 non-null   int64
#  13  wine_ratings_average  4051 non-null   float64
#  14  red/white             4051 non-null   object
# ...

# %%
all_wine.to_csv('../data/all_wine_cleaned.csv', sep='|', index=False)
